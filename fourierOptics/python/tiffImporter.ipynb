# %%
from PIL import Image
import matplotlib.pyplot as plt
import numpy as np

# %%
rootPath = "/home/daraghhollman/Main/labData/fourierOptics/"

# %%
im = Image.open(rootPath + "laser/dualSlit_40_250.tif")

imArray = np.array(im)

newIm = imArray * 70

output = Image.fromarray(newIm)

output.show()
# Out:
# (gimp-2.10:15889): GLib-GIO-CRITICAL **: 13:00:59.035: GFileInfo created without standard::is-hidden
#
# (gimp-2.10:15889): GLib-GIO-CRITICAL **: 13:00:59.035: file ../glib/gio/gfileinfo.c: line 1633 (g_file_info_get_is_hidden): should not be reached
#
# (gimp-2.10:15889): GLib-GIO-CRITICAL **: 13:00:59.035: GFileInfo created without standard::is-backup
#
# (gimp-2.10:15889): GLib-GIO-CRITICAL **: 13:00:59.035: file ../glib/gio/gfileinfo.c: line 1655 (g_file_info_get_is_backup): should not be reached
#
# (gimp-2.10:15889): GLib-GIO-CRITICAL **: 13:00:59.035: GFileInfo created without standard::is-hidden
#
# (gimp-2.10:15889): GLib-GIO-CRITICAL **: 13:00:59.035: file ../glib/gio/gfileinfo.c: line 1633 (g_file_info_get_is_hidden): should not be reached
#
# (gimp-2.10:15889): GLib-GIO-CRITICAL **: 13:00:59.035: GFileInfo created without standard::is-backup
#
# ...
